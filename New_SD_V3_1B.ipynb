# %% [markdown]
# <a href="https://colab.research.google.com/github/monsterhunters/Stable-Diffusion/blob/main/New_SD_V3_1B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# V3

# %%
#@title # **Install** 🚀
# All necessary imports goes here
from IPython.display import clear_output, display, HTML
import os, subprocess, time, glob
import zipfile
import shutil
from datetime import timedelta
from google.colab import drive
from IPython.utils import capture
from subprocess import getoutput
from urllib.parse import unquote
from google.colab.output import eval_js
# %cd /content

import time
try:
  start_colab
except:
  start_colab = int(time.time())-5

print("\033[96m") #Cyan text
# Check if gpu exist, stop if don't.
#try:
#  output
#except:
#  print('⌚ Checking GPU...', end='')
#  output = getoutput('nvidia-smi --query-gpu=gpu_name --format=csv')
#  if "name" in output:
#    gpu_name = output[5:]
#    print('\r✅ Current GPU:', gpu_name, flush=True)
#  else:
#    print('\r\033[91m❎ ERROR: No GPU detected. Please do step below to enable.\n', flush=True)
#    display(HTML("<img src='https://i.ibb.co/HC9KH17/NVIDIA-Share-23-01-02-173037.png' width='800px'/>"))
#    print('\033[91m\nIf it says "Cannot connect to GPU backend", meaning you\'ve either reached free usage limit. OR there\'s no gpu available.\n\nDon\'t mind me... I\'m destroying your current session for your own good...')
#    display(HTML("<img src='https://media.tenor.com/E9omRGF7x0AAAAAC/hitori-gotou-bocchi-rock.gif' width='500px'/>"))
#    time.sleep(5)
#    from google.colab import runtime
#    runtime.unassign()



codemaster_addon = True #@param{type: "boolean"}
install_Extension = True #@param{type: "boolean"}


from google.colab import drive
drive.mount('/content/drive')

start_install = int(time.time())

#!pip uninstall torch -y
def my_function():
    # Clone the repository
    os.system('git clone https://github.com/monsterhunters/stablecode.git')

    # Download and install dependencies
    os.system('wget https://huggingface.co/NoCrypt/fast-repo/resolve/main/ubuntu_deps.zip ; unzip ubuntu_deps.zip -d ./deps ; dpkg -i ./deps/* ; rm -rf ubuntu_deps.zip /content/deps/')
    os.system('pip uninstall torch torchaudio torchdata torchsummary torchtext torchvision triton -y')
    os.system('pip uninstall ultralytics dynamicprompts thop mediapipe onnxruntime-gpu')
    # Download files using aria2c
    aria_command = (
        "aria2c -i- -j5 -x16 -s16 -k1M -c <<EOF\n"
        "https://huggingface.co/NoCrypt/fast-repo/resolve/main/dep.tar.lz4\n"
        " out=dep.tar.lz4\n"
        "https://huggingface.co/bigbossmonster/ext/resolve/main/embbed.tar.lz4\n"
        " out=embbed.tar.lz4\n"
        "https://huggingface.co/bigbossmonster/xformers/resolve/main/xformers23torch212cu118.tar.lz4\n"
        " out=xformers23torch212cu118.tar.lz4\n"
        "https://huggingface.co/NoCrypt/fast-repo/resolve/main/cache.tar.lz4\n"
        " out=cache.tar.lz4\n"
        "EOF"
    )
    os.system(aria_command)
    print('Finishing the setup.. ')
    # Extract files using tar and lz4
    os.system('tar -xI lz4 -f dep.tar.lz4 --overwrite-dir --directory=/usr/local/lib/python3.10/dist-packages/')
 #   os.system('tar -xI lz4 -f ext3.tar.lz4 --overwrite-dir --directory=/content/stablecode/')
 #   os.system('tar -xI lz4 -f ext4.tar.lz4 --overwrite-dir --directory=/content/stablecode/')
    os.system('tar -xI lz4 -f embbed.tar.lz4 --overwrite-dir --directory=/content/stablecode/embeddings')
    os.system('tar -xI lz4 -f cache.tar.lz4 --directory=/')
    #os.system('tar -xI lz4 -f dep2.tar.lz4 --overwrite-dir --directory=/')
    os.system('tar -xI lz4 -f xformers23torch212cu118.tar.lz4 --overwrite-dir --directory=/')



    # Remove downloaded archive files
    os.system('rm -rf /content/dep.tar.lz4 /content/embbed.tar.lz4  /content/xformers23torch212cu118.tar.lz4 /content/cache.tar.lz4')
    print('Successfully install')



# Call the function
print('Unpacking.. Please be patient')
my_function()

#!echo -n {start_colab} > stablecode/static/colabTimer.txt
#if not os.path.exists("/content/stablecode"):




if codemaster_addon:


  # Function to copy files to the destination directory, checking if they exist already
  def copy_files(files, source_directory, destination_directory):
      for file in files:
          source_file = os.path.join(source_directory, file)
          destination_file = os.path.join(destination_directory, file)
          os.makedirs(destination_directory, exist_ok=True)  # Create the destination directory if it doesn't exist
          shutil.copy2(source_file, destination_file)

  def extract_all_zips(wildcards_directory, destination_wildcards_directory):
      for file in os.listdir(wildcards_directory):
          if file.endswith('.zip'):
              file_path = os.path.join(wildcards_directory, file)
              with zipfile.ZipFile(file_path, 'r') as zip_ref:
                  zip_ref.extractall(destination_wildcards_directory)

  # Update the paths and add the necessary steps

  folder_path = '/content/stablecode/extensions/Umi-AI-debloat'

  if os.path.exists(folder_path):
      shutil.rmtree(folder_path)


  if not os.path.exists("/content/stablecode/extensions/sd-dynamic-prompts"):
      # %cd /content/stablecode/extensions
      os.system('git clone https://github.com/adieyal/sd-dynamic-prompts.git')

  if not os.path.exists("/content/stablecode/plugin-for-SD"):
      # %cd /content/stablecode
      os.system('git clone https://github.com/monsterhunters/plugin-for-SD.git')



  scripts_directory = "/content/stablecode/plugin-for-SD/scripts"  # Source directory for Python files
  wildcards_directory = "/content/stablecode/plugin-for-SD/wildcards"  # Source directory for text files
 # modules_directory = "/content/stablecode/plugin-for-SD/modules"  # Source directory for text files
  embeddings_directory = "/content/stablecode/plugin-for-SD/embeddings"  # Source directory for text files
  destination_scripts_directory = "/content/stablecode/scripts"  # Destination directory for Python files
  destination_wildcards_directory = "/content/stablecode/extensions/sd-dynamic-prompts/wildcards"  # Destination directory for text files
  destination_modules_directory = "/content/stablecode/modules"  # Destination directory for text files
  destination_embeddings_directory = "/content/stablecode/embeddings"  # Destination directory for text files

  # Rest of the code...

  # Extract all ZIP files from wildcards_directory
  extract_all_zips(wildcards_directory, destination_wildcards_directory)


  def copy_files(files, source_directory, destination_directory):
      for file in files:
          source_file = os.path.join(source_directory, file)
          destination_file = os.path.join(destination_directory, file)
          os.makedirs(destination_directory, exist_ok=True)  # Create the destination directory if it doesn't exist
          shutil.copy2(source_file, destination_file)
  # Get a list of all text files and Python files in the scripts directory
  script_files = [file for file in os.listdir(scripts_directory) if file.endswith(".py")]
  # Copy Python files to the destination scripts directory, checking if they exist already
  copy_files(script_files, scripts_directory, destination_scripts_directory)
  # Get a list of all text files in the wildcards directory
  wildcard_files = [file for file in os.listdir(wildcards_directory) if file.endswith(".txt")]
  # Copy text files to the destination wildcards directory, checking if they exist already
  copy_files(wildcard_files, wildcards_directory, destination_wildcards_directory)
  # Get a list of all Python files in the modules directory
#  module_files = [file for file in os.listdir(modules_directory) if file.endswith(".py")]
  # Copy Python files to the destination modules directory, checking if they exist already
#  copy_files(module_files, modules_directory, destination_modules_directory)

  embeddings_files = [file for file in os.listdir(embeddings_directory) if file.endswith((".pt", ".bin"))]
  # Copy Python files to the destination modules directory, checking if they exist already
  copy_files(embeddings_files, embeddings_directory, destination_embeddings_directory)

#!rm rf "/content/stablecode/extensions/sd-photopea-embed-lazy"

print('optimizing')
with capture.capture_output() as cap:

    # !wget https://github.com/camenduru/gperftools/releases/download/v1.0/libtcmalloc_minimal.so.4 -O /content/libtcmalloc_minimal.so.4
    # %env LD_PRELOAD=/content/libtcmalloc_minimal.so.4

    os.environ["SAFETENSORS_FAST_GPU"]='1'
    os.environ["CUDA_MODULE_LOADING"]="LAZY"
    os.environ["colab_url"] = eval_js("google.colab.kernel.proxyPort(7860, {'cache': false})")
    os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"
    os.environ["PYTHONWARNINGS"] = "ignore"
    # %env PYTHONDONTWRITEBYTECODE=1
    os.environ["TCMALLOC_AGGRESSIVE_DECOMMIT"] = "t"
    # os.environ['PYTORCH_CUDA_ALLOC_CONF'] = "garbage_collection_threshold:0.9,max_split_size_mb:512"
    # !apt -y update -qq
    #Fix_colab
    # !wget https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64.deb
    # !dpkg -i cloudflared-linux-amd64.deb
    # !apt-get install -f
    # !cloudflared --version
    # !mv /usr/local/bin/cloudflared /usr/local/bin/wex
    # !pip install insightface==0.7.3 ultralytics dynamicprompts thop mediapipe onnxruntime-gpu gradio
    #!pip install https://files.pythonhosted.org/packages/58/df/b44a846a103476fe9b4f9bb0fe99cb787fecb48ee795c2b2c4578ca98217/ultralytics-8.1.27-py3-none-any.whl
    #!pip install https://files.pythonhosted.org/packages/55/18/ee387122d87c2f00c5a745cd1c43e25d48ffd0c072607fa2c7152c365991/dynamicprompts-0.30.4-py3-none-any.whl
    #!pip install https://files.pythonhosted.org/packages/bb/0f/72beeab4ff5221dc47127c80f8834b4bcd0cb36f6ba91c0b1d04a1233403/thop-0.1.1.post2209072238-py3-none-any.whl
    #!pip install https://files.pythonhosted.org/packages/05/3c/4ec793de693c5dcb0bbddbece6a5dfc33d23f001d9b6b8020a816d91184c/mediapipe-0.10.11-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
    #!pip install https://aiinfra.pkgs.visualstudio.com/2692857e-05ef-43b4-ba9c-ccf1c22c437c/_packaging/9387c3aa-d9ad-4513-968c-383f6f7f53b8/pypi/download/onnxruntime-gpu/1.17.1/onnxruntime_gpu-1.17.1-cp310-cp310-manylinux_2_28_x86_64.whl


#@title # **Extension** 🚀
def installExtension():
    import custom

    def downloadModel(url):
      if 'huggingface.co' in url:
        filename = url.split('/')[-1]
        filename = filename.removesuffix('?download=true')
        # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M {url}  -o {filename}
      else:
        # civitai
        # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M {url}

    AnimateDiff = False
    text2Video = False
    Deforum = False

    if AnimateDiff:
        # %cd /content/stablecode/extensions
        custom.installAnimateDiff()
        # %cd sd-webui-animatediff/model
        downloadModel('https://huggingface.co/guoyww/animatediff/resolve/main/mm_sd_v14.ckpt')
        downloadModel('https://huggingface.co/guoyww/animatediff/resolve/main/mm_sd_v15.ckpt')
        downloadModel('https://huggingface.co/guoyww/animatediff/resolve/main/mm_sd_v15_v2.ckpt')

    if text2Video:
        # %cd /content/stablecode/extensions
        custom.installtext2video()
        # %mkdir -p {root}/stablecode/models/text2video/t2v
        # %cd {root}/stablecode/models/text2video/t2v
        downloadModel('https://huggingface.co/damo-vilab/modelscope-damo-text-to-video-synthesis/resolve/main/VQGAN_autoencoder.pth')
        downloadModel('https://huggingface.co/damo-vilab/modelscope-damo-text-to-video-synthesis/resolve/main/configuration.json')
        downloadModel('https://huggingface.co/damo-vilab/modelscope-damo-text-to-video-synthesis/resolve/main/open_clip_pytorch_model.bin')
        downloadModel('https://huggingface.co/damo-vilab/modelscope-damo-text-to-video-synthesis/resolve/main/text2video_pytorch_model.pth')

    if Deforum:
        # %cd /content/stablecode/extensions
        custom.installDeforum()

    # %cd /content/stablecode/extensions
    #custom.installReactor()
    #custom.highRes()
    #custom.twoShot()
    #custom.composableLora()
    custom.locon()
    custom.llul()
    custom.ControlNet()
    custom.freeU()
    #custom.removeBg()
    #custom.umiAI()
    #custom.easyPhoto()
    #custom.layerDiffusion()
    #custom.installMultidiffusion()
    #custom.installAdditionalnetworks()
    #custom.installDreambooth()
    #custom.installRoop()
    #custom.installFacechain()
    #custom.installSadtalker()
    #!pip install insightface
    custom.installExtB()
    os.chdir('../')

if install_Extension:
    installExtension()


install_time = timedelta(seconds=time.time()-start_install)
print("\r🚀 Finished unpacking. Took","%02d:%02d:%02d ⚡\n" % (install_time.seconds / 3600, (install_time.seconds / 60) % 60, install_time.seconds % 60), end='', flush=True)
# Colab 🤝 Gradio (Colab timer integration for gradio)
# !echo -n {start_colab} > /content/stablecode/static/colabTimer.txt
print("🤝 Colab timer integration complete! You can see your colab time inside webui.")

# %%
# @markdown #### ⬅️ Civit Ai Downloader


import gradio as gr
import os
from urllib.parse import urlparse, urlunparse

api_key = "362e7d35e7592b12af266c08fc35e939"

def download_file(download_link, output_path):
    parsed_url = urlparse(download_link)
    path_components = parsed_url.path.split("/")
    modelVersionId = path_components[-1]
    dlink = "https://civitai.com/api/download/models/"+modelVersionId+"?token=" + api_key
    os.system(f"aria2c -x 16 -s 16 -k 1M -d {output_path} {dlink}")
    return "File downloaded successfully!"

demo = gr.Interface(
    fn=download_file,
    inputs=["text", "text"],  # Inputs should be provided as a list
    outputs="text",
    title="Civitai File Downloader",
    description="Enter the URL of the file you want to download and the output path:",
    allow_flagging=False
)

demo.launch(server_port=4200)
# Out:
# /usr/local/lib/python3.10/dist-packages/gradio/interface.py:328: UserWarning: The `allow_flagging` parameter in `Interface` nowtakes a string value ('auto', 'manual', or 'never'), not a boolean. Setting parameter to: 'never'.
#   warnings.warn(
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Note: opening Chrome Inspector may crash demo inside Colab notebooks.
#
# To create a public link, set `share=True` in `launch()`.

# %%
#@title # **RUN** 🚀
model_path = "/content/drive/Shareddrives/BSSG-RCN-\\(70\\)/HTZ/CodeUI/models/custom" # @param {type:"string"}
vae_path = "/content/drive/Shareddrives/BSSG-RCN-\\(70\\)/HTZ/CodeUI/models/vae" # @param {type:"string"}
lora_path = "/content/drive/Shareddrives/BSSG-RCN-\\(70\\)/HTZ/CodeUI/models/loras" # @param {type:"string"}
upscaler_path = "/content/drive/Shareddrives/BSSG-RCN-\\(70\\)/HTZ/CodeUI/models/upscale_models" # @param {type:"string"}
controlnet_path = "/content/drive/Shareddrives/BSSG-RCN-\\(70\\)/HTZ/CodeUI/models/controlnet" # @param {type:"string"}
import subprocess
import threading
import time
import socket
import urllib.request

def iframe_thread(port):
  while True:
      time.sleep(0.5)
      sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
      result = sock.connect_ex(('127.0.0.1', port))
      if result == 0:
        break
      sock.close()
  print("\nUI finished loading, trying to launch (if it gets stuck here  is having issues)\n")

  p = subprocess.Popen(["wex", "tunnel", "--url", "http://127.0.0.1:{}".format(port)], stdout=subprocess.PIPE, stderr=subprocess.PIPE)
  for line in p.stderr:
    l = line.decode()
    if "trycloudflare.com " in l:
      print("This is the URL to access UI:", l[l.find("http"):], end='')
    #print(l, end='')




threading.Thread(target=iframe_thread, daemon=True, args=(7860,)).start()
#!python launch.py  --enable-insecure-extension-access --disable-safe-unpickle --no-hashing --xformers
# !python launch.py  --enable-insecure-extension-access --disable-safe-unpickle --no-hashing --xformers  --ckpt-dir $model_path --vae-dir $vae_path --lora-dir $lora_path --esrgan-models-path $upscaler_path  --controlnet-dir $controlnet_path
#!python launch.py  --no-half-vae --listen --xformers --opt-sdp-no-mem-attention  --ckpt-dir '/content/drive/Shareddrives/BSSG-RCN-(70)/HTZ/CodeUI/models/checkpoints' --vae-dir '/content/drive/Shareddrives/BSSG-RCN-(70)/HTZ/CodeUI/models/vae' --embeddings-dir '/content/drive/Shareddrives/BSSG-RCN-(70)/HTZ/CodeUI/models/embeddings' --lora-dir '/content/drive/Shareddrives/BSSG-RCN-(70)/HTZ/CodeUI/models/loras' --esrgan-models-path '/content/drive/Shareddrives/BSSG-RCN-(70)/HTZ/CodeUI/models/upscale_models'  --controlnet-dir '/content/drive/Shareddrives/BSSG-RCN-(70)/HTZ/controlnet'
# Out:
# fatal: No names found, cannot describe anything.
# Python 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
# Version: 1.8.0-RC
# Commit hash: 53746ab07066f643704771809e032fc11c730b50
# Installing requirements
# Collecting ultralytics>=8.1.29
#   Downloading ultralytics-8.1.38-py3-none-any.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 726.9 kB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics>=8.1.29) (3.7.1)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics>=8.1.29) (4.8.0.76)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics>=8.1.29) (9.5.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics>=8.1.29) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics>=8.1.29) (2.28.1)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics>=8.1.29) (1.11.4)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics>=8.1.29) (2.1.2+cu118)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics>=8.1.29) (0.16.2+cu118)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics>=8.1.29) (4.66.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ultralytics>=8.1.29) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from ultralytics>=8.1.29) (9.0.0)
# Requirement already satisfied: thop>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics>=8.1.29) (0.1.1.post2209072238)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from ultralytics>=8.1.29) (1.5.3)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics>=8.1.29) (0.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics>=8.1.29) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics>=8.1.29) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics>=8.1.29) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics>=8.1.29) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics>=8.1.29) (1.26.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics>=8.1.29) (24.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics>=8.1.29) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics>=8.1.29) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics>=8.1.29) (2023.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics>=8.1.29) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics>=8.1.29) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics>=8.1.29) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics>=8.1.29) (2022.12.7)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics>=8.1.29) (3.13.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics>=8.1.29) (4.10.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics>=8.1.29) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics>=8.1.29) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics>=8.1.29) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics>=8.1.29) (2023.4.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics>=8.1.29) (2.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics>=8.1.29) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->ultralytics>=8.1.29) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8.0->ultralytics>=8.1.29) (1.3.0)
# Downloading ultralytics-8.1.38-py3-none-any.whl (723 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 723.3/723.3 kB 6.0 MB/s eta 0:00:00
# Installing collected packages: ultralytics
#   Attempting uninstall: ultralytics
#     Found existing installation: ultralytics 8.0.169
#     Uninstalling ultralytics-8.0.169:
#       Successfully uninstalled ultralytics-8.0.169
# Successfully installed ultralytics-8.1.38
# Collecting mediapipe>=0.10.9
#   Downloading mediapipe-0.10.11-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.7 kB)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from mediapipe>=0.10.9) (1.4.0)
# Requirement already satisfied: attrs>=19.1.0 in /usr/local/lib/python3.10/dist-packages (from mediapipe>=0.10.9) (23.2.0)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.10/dist-packages (from mediapipe>=0.10.9) (24.3.25)
# Requirement already satisfied: jax in /usr/local/lib/python3.10/dist-packages (from mediapipe>=0.10.9) (0.4.23)
# Requirement already satisfied: jaxlib in /usr/local/lib/python3.10/dist-packages (from mediapipe>=0.10.9) (0.4.23+cuda12.cudnn89)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mediapipe>=0.10.9) (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mediapipe>=0.10.9) (1.26.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from mediapipe>=0.10.9) (2.1.2+cu118)
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.10/dist-packages (from mediapipe>=0.10.9) (4.8.0.76)
# Requirement already satisfied: protobuf<4,>=3.11 in /usr/local/lib/python3.10/dist-packages (from mediapipe>=0.10.9) (3.20.3)
# Requirement already satisfied: sounddevice>=0.4.4 in /usr/local/lib/python3.10/dist-packages (from mediapipe>=0.10.9) (0.4.6)
# Requirement already satisfied: CFFI>=1.0 in /usr/local/lib/python3.10/dist-packages (from sounddevice>=0.4.4->mediapipe>=0.10.9) (1.16.0)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from jax->mediapipe>=0.10.9) (0.2.0)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.10/dist-packages (from jax->mediapipe>=0.10.9) (3.3.0)
# Requirement already satisfied: scipy>=1.9 in /usr/local/lib/python3.10/dist-packages (from jax->mediapipe>=0.10.9) (1.11.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe>=0.10.9) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe>=0.10.9) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe>=0.10.9) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe>=0.10.9) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe>=0.10.9) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe>=0.10.9) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe>=0.10.9) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe>=0.10.9) (2.8.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->mediapipe>=0.10.9) (3.13.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->mediapipe>=0.10.9) (4.10.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->mediapipe>=0.10.9) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->mediapipe>=0.10.9) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->mediapipe>=0.10.9) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->mediapipe>=0.10.9) (2023.4.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch->mediapipe>=0.10.9) (2.1.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe>=0.10.9) (2.21)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mediapipe>=0.10.9) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->mediapipe>=0.10.9) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->mediapipe>=0.10.9) (1.3.0)
# Downloading mediapipe-0.10.11-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (35.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.6/35.6 MB 34.7 MB/s eta 0:00:00
# Installing collected packages: mediapipe
#   Attempting uninstall: mediapipe
#     Found existing installation: mediapipe 0.10.3
#     Uninstalling mediapipe-0.10.3:
#       Successfully uninstalled mediapipe-0.10.3
# Successfully installed mediapipe-0.10.11
# CUDA 11.8
# Launching Web UI with arguments: --enable-insecure-extension-access --disable-safe-unpickle --no-hashing --xformers --ckpt-dir /content/drive/Shareddrives/BSSG-RCN-(70)/HTZ/CodeUI/models/custom --vae-dir /content/drive/Shareddrives/BSSG-RCN-(70)/HTZ/CodeUI/models/vae --lora-dir /content/drive/Shareddrives/BSSG-RCN-(70)/HTZ/CodeUI/models/loras --esrgan-models-path /content/drive/Shareddrives/BSSG-RCN-(70)/HTZ/CodeUI/models/upscale_models --controlnet-dir /content/drive/Shareddrives/BSSG-RCN-(70)/HTZ/CodeUI/models/controlnet
# Additional Network extension not installed, Only hijack built-in lora
# LoCon Extension hijack built-in lora successfully
# Tag Autocomplete: Could not locate model-keyword extension, Lora trigger word completion will be limited to those added through the extra networks menu.
# Downloading face_yolov8n.pt: 100% 6.23M/6.23M [00:00<00:00, 69.4MB/s]
# Downloading face_yolov8s.pt: 100% 22.5M/22.5M [00:00<00:00, 208MB/s]
# Downloading hand_yolov8n.pt: 100% 6.24M/6.24M [00:00<00:00, 204MB/s]
# Downloading person_yolov8n-seg.pt: 100% 6.78M/6.78M [00:00<00:00, 199MB/s]
# Downloading person_yolov8s-seg.pt: 100% 23.9M/23.9M [00:00<00:00, 198MB/s]
# Downloading yolov8x-worldv2.pt: 100% 146M/146M [00:01<00:00, 146MB/s]
# [-] ADetailer initialized. version: 24.3.5, num models: 10
# ControlNet preprocessor location: /content/stablecode/extensions/sd-webui-controlnet/annotator/downloads
# 2024-03-31 08:40:21,737 - ControlNet - INFO - ControlNet v1.1.442
# 2024-03-31 08:40:33,135 - ControlNet - INFO - ControlNet v1.1.442
# [sd-webui-freeu] Controlnet support: *enabled*
# 08:40:34 - ReActor - STATUS - Running v0.7.0-b7 on Device: CUDA
# Loading weights [None] from /content/drive/Shareddrives/BSSG-RCN-(70)/HTZ/CodeUI/models/custom/ponyDiffusionV6XL_v6StartWithThisOne.safetensors
# 2024-03-31 08:40:37,685 - ControlNet - INFO - ControlNet UI callback registered.
# Running on local URL:  http://127.0.0.1:7860
#
# To create a public link, set `share=True` in `launch()`.
# Startup time: 86.7s (prepare environment: 36.4s, import torch: 16.0s, import gradio: 1.5s, setup paths: 3.2s, initialize shared: 0.3s, other imports: 1.6s, list SD models: 3.5s, load scripts: 20.2s, initialize extra networks: 0.1s, create ui: 2.7s, gradio launch: 1.1s).
#
# UI finished loading, trying to launch (if it gets stuck here  is having issues)
#
# This is the URL to access UI: https://cayman-music-amateur-producers.trycloudflare.com                                  |
# Creating model from config: /content/stablecode/repositories/generative-models/configs/inference/sd_xl_base.yaml
# Loading VAE weights specified in settings: /content/drive/Shareddrives/BSSG-RCN-(70)/HTZ/CodeUI/models/vae/sdxlVae.yhPi.safetensors
# Applying attention optimization: sdp... done.
# Model loaded in 46.4s (load weights from disk: 5.8s, create model: 0.6s, apply weights to model: 36.7s, apply half(): 0.2s, load VAE: 2.0s, load textual inversion embeddings: 0.2s, calculate empty prompt: 0.8s).
#   0% 0/20 [00:00<?, ?it/s]
#   5% 1/20 [00:07<02:22,  7.51s/it]
#  10% 2/20 [00:07<01:00,  3.36s/it]
#  15% 3/20 [00:08<00:34,  2.05s/it]
#  20% 4/20 [00:08<00:22,  1.42s/it]
#  25% 5/20 [00:09<00:16,  1.08s/it]
#  30% 6/20 [00:09<00:12,  1.13it/s]
#  35% 7/20 [00:10<00:09,  1.30it/s]
#  40% 8/20 [00:10<00:08,  1.42it/s]
#  45% 9/20 [00:11<00:06,  1.69it/s]
#  50% 10/20 [00:11<00:05,  1.96it/s]
#  55% 11/20 [00:12<00:04,  2.17it/s]
#  60% 12/20 [00:12<00:03,  2.34it/s]
#  65% 13/20 [00:12<00:02,  2.52it/s]
#  70% 14/20 [00:13<00:02,  2.51it/s]
#  75% 15/20 [00:13<00:01,  2.64it/s]
#  80% 16/20 [00:13<00:01,  2.72it/s]
#  85% 17/20 [00:14<00:01,  2.72it/s]
#  90% 18/20 [00:14<00:00,  2.75it/s]
#  95% 19/20 [00:14<00:00,  2.80it/s]
# 100% 20/20 [00:15<00:00,  1.32it/s]
#
# Total progress: 100% 20/20 [00:08<00:00,  2.47it/s]
#   0% 0/20 [00:00<?, ?it/s]
#   5% 1/20 [00:00<00:10,  1.90it/s]
#  10% 2/20 [00:00<00:07,  2.37it/s]
#  15% 3/20 [00:01<00:06,  2.61it/s]
#  20% 4/20 [00:01<00:05,  2.69it/s]
#  25% 5/20 [00:01<00:05,  2.74it/s]
#  30% 6/20 [00:02<00:05,  2.80it/s]
#  35% 7/20 [00:02<00:04,  2.80it/s]
#  40% 8/20 [00:02<00:04,  2.79it/s]
#  45% 9/20 [00:03<00:03,  2.79it/s]
#  50% 10/20 [00:03<00:03,  2.80it/s]
#  55% 11/20 [00:04<00:03,  2.85it/s]
#  60% 12/20 [00:04<00:02,  2.86it/s]
#  65% 13/20 [00:04<00:02,  2.73it/s]
#  70% 14/20 [00:05<00:02,  2.78it/s]
#  75% 15/20 [00:05<00:01,  2.81it/s]
#  80% 16/20 [00:05<00:01,  2.81it/s]
#  85% 17/20 [00:06<00:01,  2.83it/s]
#  90% 18/20 [00:06<00:00,  2.85it/s]
#  95% 19/20 [00:06<00:00,  2.83it/s]
# 100% 20/20 [00:07<00:00,  2.77it/s]
#
# Total progress: 100% 20/20 [00:07<00:00,  2.83it/s]
# INFO:sd_dynamic_prompts.dynamic_prompting:Prompt matrix will create 4 images in a total of 1 batches.
#   0% 0/20 [00:00<?, ?it/s]
#   5% 1/20 [00:01<00:25,  1.35s/it]
#  10% 2/20 [00:02<00:23,  1.28s/it]
#  15% 3/20 [00:03<00:21,  1.26s/it]
#  20% 4/20 [00:05<00:22,  1.40s/it]
#  25% 5/20 [00:06<00:20,  1.35s/it]
#  30% 6/20 [00:07<00:18,  1.31s/it]
#  35% 7/20 [00:09<00:16,  1.29s/it]
#  40% 8/20 [00:10<00:15,  1.28s/it]
#  45% 9/20 [00:11<00:13,  1.26s/it]
#  50% 10/20 [00:12<00:12,  1.26s/it]
#  55% 11/20 [00:14<00:11,  1.25s/it]
#  60% 12/20 [00:15<00:10,  1.25s/it]
#  65% 13/20 [00:16<00:08,  1.25s/it]
#  70% 14/20 [00:17<00:07,  1.25s/it]
#  75% 15/20 [00:19<00:06,  1.25s/it]
#  80% 16/20 [00:20<00:05,  1.26s/it]
#  85% 17/20 [00:21<00:03,  1.26s/it]
#  90% 18/20 [00:22<00:02,  1.26s/it]
#  95% 19/20 [00:24<00:01,  1.26s/it]
# 100% 20/20 [00:25<00:00,  1.27s/it]
#
# Total progress: 100% 20/20 [00:26<00:00,  1.34s/it]
# INFO:sd_dynamic_prompts.dynamic_prompting:Prompt matrix will create 4 images in a total of 1 batches.
#
#   0% 0/20 [00:00<?, ?it/s]
#   5% 1/20 [00:01<00:25,  1.34s/it]
#  10% 2/20 [00:02<00:23,  1.30s/it]
#  15% 3/20 [00:03<00:21,  1.28s/it]
#  20% 4/20 [00:05<00:20,  1.28s/it]
#  25% 5/20 [00:06<00:19,  1.28s/it]
#  30% 6/20 [00:07<00:17,  1.28s/it]
#  35% 7/20 [00:09<00:16,  1.29s/it]
#  40% 8/20 [00:10<00:15,  1.29s/it]
#  45% 9/20 [00:11<00:14,  1.29s/it]
#  50% 10/20 [00:12<00:12,  1.29s/it]
#  55% 11/20 [00:14<00:11,  1.29s/it]
#  60% 12/20 [00:15<00:10,  1.30s/it]
#  65% 13/20 [00:16<00:09,  1.30s/it]
#  70% 14/20 [00:18<00:07,  1.31s/it]
#  75% 15/20 [00:19<00:06,  1.31s/it]
#  80% 16/20 [00:20<00:05,  1.32s/it]
#  85% 17/20 [00:22<00:03,  1.32s/it]
#  90% 18/20 [00:23<00:02,  1.32s/it]
#  95% 19/20 [00:24<00:01,  1.32s/it]
# 100% 20/20 [00:26<00:00,  1.30s/it]
#   0% 0/20 [00:00<?, ?it/s]
#   5% 1/20 [00:05<01:46,  5.59s/it]
#  10% 2/20 [00:11<01:39,  5.52s/it]
#  15% 3/20 [00:16<01:33,  5.49s/it]
#  20% 4/20 [00:21<01:27,  5.46s/it]
#  25% 5/20 [00:27<01:21,  5.43s/it]
#  30% 6/20 [00:32<01:15,  5.40s/it]
#  35% 7/20 [00:37<01:09,  5.38s/it]
#  40% 8/20 [00:43<01:04,  5.37s/it]
#  45% 9/20 [00:48<00:58,  5.36s/it]
#  50% 10/20 [00:53<00:53,  5.35s/it]
#  55% 11/20 [00:59<00:48,  5.35s/it]
#  60% 12/20 [01:04<00:42,  5.36s/it]
#  65% 13/20 [01:10<00:37,  5.36s/it]
#  70% 14/20 [01:15<00:32,  5.37s/it]
#  75% 15/20 [01:20<00:26,  5.39s/it]
#  80% 16/20 [01:26<00:21,  5.40s/it]
#  85% 17/20 [01:31<00:16,  5.41s/it]
#  90% 18/20 [01:37<00:10,  5.42s/it]
#  95% 19/20 [01:42<00:05,  5.42s/it]
# 100% 20/20 [01:48<00:00,  5.40s/it]
#
# 0: 640x448 1 face, 125.1ms
# Speed: 27.9ms preprocess, 125.1ms inference, 127.6ms postprocess per image at shape (1, 3, 640, 448)
# 100% 9/9 [00:11<00:00,  1.25s/it]
#
# 0: 640x448 1 face, 9.9ms
# Speed: 3.4ms preprocess, 9.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 448)
# 100% 9/9 [00:11<00:00,  1.24s/it]
#
# 0: 640x448 1 face, 8.6ms
# Speed: 3.2ms preprocess, 8.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 448)
# 100% 9/9 [00:10<00:00,  1.21s/it]
#
# 0: 640x448 1 face, 8.3ms
# Speed: 3.5ms preprocess, 8.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 448)
# 100% 9/9 [00:11<00:00,  1.25s/it]
# INFO:sd_dynamic_prompts.dynamic_prompting:Prompt matrix will create 4 images in a total of 1 batches.
#
# Total progress: 100% 40/40 [03:16<00:00,  4.91s/it]
# INFO:sd_dynamic_prompts.dynamic_prompting:Prompt matrix will create 4 images in a total of 1 batches.
#
#   0% 0/20 [00:00<?, ?it/s]
#   5% 1/20 [00:01<00:25,  1.32s/it]
#  10% 2/20 [00:02<00:23,  1.28s/it]
#  15% 3/20 [00:03<00:21,  1.26s/it]
#  20% 4/20 [00:05<00:20,  1.26s/it]
#  25% 5/20 [00:06<00:18,  1.26s/it]
#  30% 6/20 [00:07<00:17,  1.26s/it]
#  35% 7/20 [00:09<00:18,  1.40s/it]
#  40% 8/20 [00:11<00:18,  1.53s/it]
#  45% 9/20 [00:12<00:16,  1.54s/it]
#  50% 10/20 [00:13<00:14,  1.45s/it]
#  55% 11/20 [00:15<00:12,  1.40s/it]
#  60% 12/20 [00:16<00:10,  1.36s/it]
#  65% 13/20 [00:17<00:09,  1.36s/it]
#  70% 14/20 [00:19<00:08,  1.34s/it]
#  75% 15/20 [00:20<00:06,  1.32s/it]
#  80% 16/20 [00:21<00:05,  1.32s/it]
#  85% 17/20 [00:23<00:04,  1.44s/it]
#  90% 18/20 [00:25<00:03,  1.55s/it]
#  95% 19/20 [00:26<00:01,  1.54s/it]
# 100% 20/20 [00:28<00:00,  1.40s/it]
#   0% 0/20 [00:00<?, ?it/s]
#   5% 1/20 [00:05<01:45,  5.57s/it]
#  10% 2/20 [00:11<01:39,  5.55s/it]
#  15% 3/20 [00:16<01:33,  5.52s/it]
#  20% 4/20 [00:22<01:27,  5.49s/it]
#  25% 5/20 [00:27<01:22,  5.47s/it]
#  30% 6/20 [00:32<01:16,  5.43s/it]
#  35% 7/20 [00:38<01:10,  5.41s/it]
#  40% 8/20 [00:43<01:04,  5.39s/it]
#  45% 9/20 [00:48<00:59,  5.37s/it]
#  50% 10/20 [00:54<00:53,  5.36s/it]
#  55% 11/20 [00:59<00:48,  5.35s/it]
#  60% 12/20 [01:04<00:42,  5.36s/it]
#  65% 13/20 [01:10<00:37,  5.36s/it]
#  70% 14/20 [01:15<00:32,  5.37s/it]
#  75% 15/20 [01:21<00:26,  5.38s/it]
#  80% 16/20 [01:26<00:21,  5.39s/it]
#  85% 17/20 [01:31<00:16,  5.40s/it]
#  90% 18/20 [01:37<00:10,  5.41s/it]
#  95% 19/20 [01:42<00:05,  5.42s/it]
# 100% 20/20 [01:48<00:00,  5.41s/it]
#
# 0: 640x448 1 face, 128.8ms
# Speed: 3.8ms preprocess, 128.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 448)
# 100% 9/9 [00:11<00:00,  1.26s/it]
#
# 0: 640x448 1 face, 9.8ms
# Speed: 2.9ms preprocess, 9.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 448)
# 100% 9/9 [00:11<00:00,  1.24s/it]
#
# 0: 640x448 1 face, 8.6ms
# Speed: 2.9ms preprocess, 8.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 448)
# 100% 9/9 [00:10<00:00,  1.20s/it]
#
# 0: 640x448 1 face, 9.2ms
# Speed: 3.4ms preprocess, 9.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 448)
# 100% 9/9 [00:11<00:00,  1.26s/it]
# INFO:sd_dynamic_prompts.dynamic_prompting:Prompt matrix will create 4 images in a total of 1 batches.
#
# Total progress: 100% 40/40 [03:20<00:00,  5.02s/it]
# INFO:sd_dynamic_prompts.dynamic_prompting:Prompt matrix will create 80 images in a total of 20 batches.
#
#   0% 0/20 [00:00<?, ?it/s]
#   5% 1/20 [00:01<00:34,  1.81s/it]
#  10% 2/20 [00:03<00:27,  1.50s/it]
#  15% 3/20 [00:04<00:23,  1.40s/it]
#  20% 4/20 [00:05<00:21,  1.36s/it]
#  25% 5/20 [00:06<00:20,  1.34s/it]
#  30% 6/20 [00:08<00:18,  1.33s/it]
#  35% 7/20 [00:09<00:17,  1.32s/it]
#  40% 8/20 [00:10<00:15,  1.32s/it]
#  45% 9/20 [00:12<00:15,  1.43s/it]
#  50% 10/20 [00:14<00:15,  1.54s/it]
#  55% 11/20 [00:15<00:13,  1.55s/it]
#  60% 12/20 [00:17<00:11,  1.48s/it]
#  65% 13/20 [00:18<00:10,  1.44s/it]
#  70% 14/20 [00:19<00:08,  1.42s/it]
#  75% 15/20 [00:21<00:06,  1.40s/it]
#  80% 16/20 [00:22<00:05,  1.38s/it]
#  85% 17/20 [00:24<00:04,  1.37s/it]
#  90% 18/20 [00:25<00:02,  1.36s/it]
#  95% 19/20 [00:27<00:01,  1.49s/it]
# 100% 20/20 [00:28<00:00,  1.45s/it]
#   0% 0/20 [00:00<?, ?it/s]
#   5% 1/20 [00:05<01:44,  5.51s/it]
#  10% 2/20 [00:10<01:38,  5.49s/it]
#  15% 3/20 [00:16<01:32,  5.46s/it]
#  20% 4/20 [00:21<01:26,  5.44s/it]
#  25% 5/20 [00:27<01:21,  5.41s/it]
#  30% 6/20 [00:32<01:15,  5.39s/it]
#  35% 7/20 [00:37<01:09,  5.37s/it]
#  40% 8/20 [00:43<01:04,  5.36s/it]
#  45% 9/20 [00:48<00:58,  5.36s/it]
#  50% 10/20 [00:53<00:53,  5.36s/it]
#  55% 11/20 [00:59<00:48,  5.37s/it]
#  60% 12/20 [01:04<00:43,  5.38s/it]
#  65% 13/20 [01:10<00:37,  5.39s/it]
#  70% 14/20 [01:15<00:32,  5.40s/it]
#  75% 15/20 [01:20<00:27,  5.41s/it]
#  80% 16/20 [01:26<00:21,  5.42s/it]
#  85% 17/20 [01:31<00:16,  5.43s/it]
#  90% 18/20 [01:37<00:10,  5.43s/it]
#  95% 19/20 [01:42<00:05,  5.43s/it]
# 100% 20/20 [01:48<00:00,  5.41s/it]
#
# 0: 640x448 1 face, 124.3ms
# Speed: 4.5ms preprocess, 124.3ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 448)
# 100% 9/9 [00:11<00:00,  1.25s/it]
#
# 0: 640x448 1 face, 8.9ms
# Speed: 2.9ms preprocess, 8.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 448)
# 100% 9/9 [00:11<00:00,  1.25s/it]
#
# 0: 640x448 1 face, 10.5ms
# Speed: 3.5ms preprocess, 10.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 448)
# 100% 9/9 [00:10<00:00,  1.21s/it]
#
# 0: 640x448 1 face, 8.4ms
# Speed: 3.1ms preprocess, 8.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 448)
# 100% 9/9 [00:11<00:00,  1.22s/it]
# INFO:sd_dynamic_prompts.dynamic_prompting:Prompt matrix will create 80 images in a total of 20 batches.
#   0% 0/20 [00:00<?, ?it/s]
#   5% 1/20 [00:01<00:25,  1.34s/it]
#  10% 2/20 [00:02<00:23,  1.30s/it]
#  15% 3/20 [00:03<00:21,  1.29s/it]
#  20% 4/20 [00:05<00:20,  1.30s/it]
#  25% 5/20 [00:06<00:19,  1.29s/it]
#  30% 6/20 [00:08<00:19,  1.38s/it]
#  35% 7/20 [00:09<00:19,  1.52s/it]
#  40% 8/20 [00:11<00:18,  1.55s/it]
#  45% 9/20 [00:12<00:16,  1.47s/it]
#  50% 10/20 [00:14<00:14,  1.43s/it]
#  55% 11/20 [00:15<00:12,  1.40s/it]
#  60% 12/20 [00:16<00:11,  1.38s/it]
#  65% 13/20 [00:18<00:09,  1.37s/it]
#  70% 14/20 [00:19<00:08,  1.36s/it]
#  75% 15/20 [00:20<00:06,  1.35s/it]
#  80% 16/20 [00:22<00:05,  1.44s/it]
#  85% 17/20 [00:24<00:04,  1.55s/it]
#  90% 18/20 [00:25<00:03,  1.56s/it]
#  95% 19/20 [00:27<00:01,  1.48s/it]
# 100% 20/20 [00:28<00:00,  1.42s/it]
#   0% 0/20 [00:00<?, ?it/s]
#   5% 1/20 [00:05<01:44,  5.47s/it]
#  10% 2/20 [00:10<01:38,  5.46s/it]
#  15% 3/20 [00:16<01:32,  5.43s/it]
#  20% 4/20 [00:21<01:26,  5.41s/it]
#  25% 5/20 [00:27<01:20,  5.39s/it]
#  30% 6/20 [00:32<01:15,  5.38s/it]
#  35% 7/20 [00:37<01:09,  5.37s/it]
#  40% 8/20 [00:43<01:04,  5.36s/it]
#  45% 9/20 [00:48<00:58,  5.35s/it]
#  50% 10/20 [00:53<00:53,  5.36s/it]
#  55% 11/20 [00:59<00:48,  5.37s/it]
#  60% 12/20 [01:04<00:43,  5.38s/it]
#  65% 13/20 [01:10<00:37,  5.39s/it]
#  70% 14/20 [01:15<00:32,  5.40s/it]
#  75% 15/20 [01:20<00:27,  5.42s/it]
#  80% 16/20 [01:26<00:21,  5.43s/it]
#  85% 17/20 [01:31<00:16,  5.44s/it]
#  90% 18/20 [01:37<00:10,  5.44s/it]
#  95% 19/20 [01:42<00:05,  5.44s/it]
# 100% 20/20 [01:48<00:00,  5.41s/it]
#
# 0: 640x448 1 face, 14.1ms
# Speed: 3.7ms preprocess, 14.1ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 448)
# 100% 9/9 [00:11<00:00,  1.25s/it]
#
# 0: 640x448 1 face, 8.6ms
# Speed: 2.9ms preprocess, 8.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 448)
# 100% 9/9 [00:11<00:00,  1.25s/it]
#
# 0: 640x448 1 face, 8.7ms
# Speed: 3.3ms preprocess, 8.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 448)
# 100% 9/9 [00:10<00:00,  1.22s/it]
#
# 0: 640x448 1 face, 8.5ms
# Speed: 3.3ms preprocess, 8.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 448)
# 100% 9/9 [00:11<00:00,  1.25s/it]
# INFO:sd_dynamic_prompts.dynamic_prompting:Prompt matrix will create 80 images in a total of 20 batches.
#   0% 0/20 [00:00<?, ?it/s]
#   5% 1/20 [00:01<00:25,  1.34s/it]
#  10% 2/20 [00:02<00:23,  1.30s/it]
#  15% 3/20 [00:04<00:22,  1.35s/it]
#  20% 4/20 [00:05<00:24,  1.52s/it]
#  25% 5/20 [00:07<00:24,  1.63s/it]
#  30% 6/20 [00:08<00:21,  1.52s/it]
#  35% 7/20 [00:10<00:18,  1.44s/it]
#  40% 8/20 [00:11<00:16,  1.40s/it]
#  45% 9/20 [00:12<00:15,  1.37s/it]
#  50% 10/20 [00:14<00:13,  1.35s/it]
#  55% 11/20 [00:15<00:12,  1.33s/it]
#  60% 12/20 [00:16<00:10,  1.34s/it]
#  65% 13/20 [00:18<00:09,  1.40s/it]
#  70% 14/20 [00:20<00:09,  1.51s/it]
#  75% 15/20 [00:21<00:07,  1.57s/it]
#  80% 16/20 [00:23<00:05,  1.50s/it]
#  85% 17/20 [00:24<00:04,  1.45s/it]
#  90% 18/20 [00:25<00:02,  1.41s/it]
#  95% 19/20 [00:27<00:01,  1.38s/it]
# 100% 20/20 [00:28<00:00,  1.42s/it]
#   0% 0/20 [00:00<?, ?it/s]
#   5% 1/20 [00:05<01:44,  5.52s/it]
#  10% 2/20 [00:11<01:38,  5.50s/it]
#  15% 3/20 [00:16<01:33,  5.48s/it]
#  20% 4/20 [00:21<01:27,  5.46s/it]
#  25% 5/20 [00:27<01:21,  5.43s/it]
#  30% 6/20 [00:32<01:15,  5.41s/it]
#  35% 7/20 [00:38<01:10,  5.40s/it]
#  40% 8/20 [00:43<01:04,  5.38s/it]
#  45% 9/20 [00:48<00:59,  5.38s/it]
#  50% 10/20 [00:54<00:53,  5.38s/it]
#  55% 11/20 [00:59<00:48,  5.38s/it]
#  60% 12/20 [01:04<00:43,  5.39s/it]
#  65% 13/20 [01:10<00:37,  5.39s/it]
#  70% 14/20 [01:15<00:32,  5.40s/it]
#  75% 15/20 [01:21<00:27,  5.40s/it]
#  80% 16/20 [01:26<00:21,  5.41s/it]
#  85% 17/20 [01:31<00:16,  5.41s/it]
#  90% 18/20 [01:37<00:10,  5.42s/it]
#  95% 19/20 [01:42<00:05,  5.42s/it]
# 100% 20/20 [01:48<00:00,  5.41s/it]
#
# 0: 640x448 1 face, 24.8ms
# Speed: 4.7ms preprocess, 24.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 448)
# 100% 9/9 [00:10<00:00,  1.11s/it]
#
# 0: 640x448 1 face, 12.0ms
# Speed: 4.4ms preprocess, 12.0ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 448)
# 100% 9/9 [00:10<00:00,  1.17s/it]
#
# 0: 640x448 1 face, 11.7ms
# Speed: 3.6ms preprocess, 11.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 448)
# 100% 9/9 [00:10<00:00,  1.21s/it]
#
# 0: 640x448 1 face, 8.2ms
# Speed: 3.1ms preprocess, 8.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 448)
# 100% 9/9 [00:11<00:00,  1.25s/it]
# INFO:sd_dynamic_prompts.dynamic_prompting:Prompt matrix will create 80 images in a total of 20 batches.
#   0% 0/20 [00:00<?, ?it/s]
#   5% 1/20 [00:01<00:29,  1.56s/it]
#  10% 2/20 [00:03<00:30,  1.69s/it]
#  15% 3/20 [00:05<00:28,  1.69s/it]
#  20% 4/20 [00:06<00:24,  1.53s/it]
#  25% 5/20 [00:07<00:21,  1.45s/it]
#  30% 6/20 [00:08<00:19,  1.40s/it]
#  35% 7/20 [00:10<00:17,  1.37s/it]
#  40% 8/20 [00:11<00:16,  1.36s/it]
#  45% 9/20 [00:12<00:14,  1.34s/it]
#  50% 10/20 [00:14<00:13,  1.34s/it]
#  55% 11/20 [00:15<00:12,  1.40s/it]
#  60% 12/20 [00:17<00:12,  1.57s/it]
#  65% 13/20 [00:19<00:11,  1.57s/it]
#  70% 14/20 [00:20<00:08,  1.50s/it]
#  75% 15/20 [00:21<00:07,  1.45s/it]
#  80% 16/20 [00:23<00:05,  1.41s/it]
#  85% 17/20 [00:24<00:04,  1.39s/it]
#  90% 18/20 [00:25<00:02,  1.37s/it]
#  95% 19/20 [00:27<00:01,  1.35s/it]
# 100% 20/20 [00:28<00:00,  1.43s/it]
#   0% 0/20 [00:00<?, ?it/s]
#   5% 1/20 [00:05<01:43,  5.47s/it]
#  10% 2/20 [00:10<01:37,  5.43s/it]
#  15% 3/20 [00:16<01:31,  5.40s/it]
#  20% 4/20 [00:21<01:26,  5.38s/it]
#  25% 5/20 [00:26<01:20,  5.36s/it]
#  30% 6/20 [00:32<01:14,  5.36s/it]
#  35% 7/20 [00:37<01:09,  5.35s/it]
#  40% 8/20 [00:42<01:04,  5.35s/it]
#  45% 9/20 [00:48<00:58,  5.36s/it]
#  50% 10/20 [00:53<00:53,  5.37s/it]
#  55% 11/20 [00:59<00:48,  5.39s/it]
#  60% 12/20 [01:04<00:43,  5.40s/it]
#  65% 13/20 [01:10<00:37,  5.42s/it]
#  70% 14/20 [01:15<00:32,  5.43s/it]
#  75% 15/20 [01:20<00:27,  5.44s/it]
#  80% 16/20 [01:26<00:21,  5.44s/it]
#  85% 17/20 [01:31<00:16,  5.45s/it]
#  90% 18/20 [01:37<00:10,  5.44s/it]
#  95% 19/20 [01:42<00:05,  5.44s/it]
# 100% 20/20 [01:48<00:00,  5.41s/it]
#
# 0: 640x448 1 face, 13.4ms
# Speed: 3.8ms preprocess, 13.4ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 448)
# 100% 9/9 [00:11<00:00,  1.24s/it]
#
# 0: 640x448 1 face, 10.5ms
# Speed: 3.1ms preprocess, 10.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 448)
# 100% 9/9 [00:09<00:00,  1.11s/it]
#
# 0: 640x448 1 face, 15.1ms
# Speed: 4.4ms preprocess, 15.1ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 448)
# 100% 9/9 [00:09<00:00,  1.06s/it]
#
# 0: 640x448 1 face, 10.9ms
# Speed: 4.5ms preprocess, 10.9ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 448)
# 100% 9/9 [00:10<00:00,  1.11s/it]
# INFO:sd_dynamic_prompts.dynamic_prompting:Prompt matrix will create 80 images in a total of 20 batches.
#   0% 0/20 [00:00<?, ?it/s]
#   5% 1/20 [00:01<00:26,  1.37s/it]
#  10% 2/20 [00:02<00:23,  1.32s/it]
#  15% 3/20 [00:03<00:22,  1.30s/it]
#  20% 4/20 [00:05<00:20,  1.30s/it]
#  25% 5/20 [00:06<00:19,  1.30s/it]
#  30% 6/20 [00:07<00:18,  1.30s/it]
#  35% 7/20 [00:09<00:16,  1.30s/it]
#  40% 8/20 [00:10<00:15,  1.31s/it]
#  45% 9/20 [00:12<00:16,  1.46s/it]
#  50% 10/20 [00:14<00:15,  1.57s/it]
#  55% 11/20 [00:15<00:13,  1.50s/it]
#  60% 12/20 [00:16<00:11,  1.46s/it]
#  65% 13/20 [00:18<00:09,  1.42s/it]
#  70% 14/20 [00:19<00:08,  1.39s/it]
#  75% 15/20 [00:20<00:06,  1.38s/it]
#  80% 16/20 [00:22<00:05,  1.36s/it]
#  85% 17/20 [00:23<00:04,  1.35s/it]
#  90% 18/20 [00:24<00:02,  1.40s/it]
#  95% 19/20 [00:26<00:01,  1.54s/it]
# 100% 20/20 [00:28<00:00,  1.43s/it]
#   0% 0/20 [00:00<?, ?it/s]
#   5% 1/20 [00:05<01:44,  5.51s/it]
#  10% 2/20 [00:10<01:38,  5.46s/it]
#  15% 3/20 [00:16<01:32,  5.44s/it]
#  20% 4/20 [00:21<01:26,  5.41s/it]
#  25% 5/20 [00:27<01:20,  5.39s/it]
#  30% 6/20 [00:32<01:15,  5.37s/it]
#  35% 7/20 [00:37<01:09,  5.36s/it]
#  40% 8/20 [00:43<01:04,  5.36s/it]
#  45% 9/20 [00:48<00:58,  5.36s/it]
#  50% 10/20 [00:53<00:53,  5.36s/it]
#  55% 11/20 [00:59<00:48,  5.37s/it]
#  60% 12/20 [01:04<00:43,  5.38s/it]
#  65% 13/20 [01:10<00:37,  5.40s/it]
#  70% 14/20 [01:15<00:32,  5.41s/it]
#  75% 15/20 [01:20<00:27,  5.42s/it]
#  80% 16/20 [01:26<00:21,  5.43s/it]
#  85% 17/20 [01:31<00:16,  5.43s/it]
#  90% 18/20 [01:37<00:10,  5.43s/it]
#  95% 19/20 [01:42<00:05,  5.43s/it]
# 100% 20/20 [01:48<00:00,  5.41s/it]
#
# 0: 640x448 1 face, 15.7ms
# Speed: 4.4ms preprocess, 15.7ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 448)
# 100% 9/9 [00:11<00:00,  1.28s/it]
#
# 0: 640x448 1 face, 8.4ms
# Speed: 3.1ms preprocess, 8.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 448)
#  44% 4/9 [00:04<00:05,  1.05s/it]
